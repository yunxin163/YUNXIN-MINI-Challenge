# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = './stargan_rafd/results/8-images.jpg'
img = cv2.imread(img_path)

fig = plt.figure(figsize=(16, 9))
plt.subplot(121)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original')
plt.show()
